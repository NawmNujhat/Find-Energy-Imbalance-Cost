# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json
# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
from colorama import Fore, Style, init;

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_training=pd.read_csv('/kaggle/input/predict-energy-behavior-of-prosumers/train.csv')
df_client=pd.read_csv('/kaggle/input/predict-energy-behavior-of-prosumers/client.csv')
df_electricity_prices=pd.read_csv('/kaggle/input/predict-energy-behavior-of-prosumers/electricity_prices.csv')
df_weather_to_country=pd.read_csv('/kaggle/input/predict-energy-behavior-of-prosumers/weather_station_to_county_mapping.csv')
df_gas_prices=pd.read_csv('/kaggle/input/predict-energy-behavior-of-prosumers/gas_prices.csv')
df_historical_weather=pd.read_csv('/kaggle/input/predict-energy-behavior-of-prosumers/historical_weather.csv')
df_forecast_weather=pd.read_csv('/kaggle/input/predict-energy-behavior-of-prosumers/forecast_weather.csv')

# %%
df_training.head(5)

# %%
df_client.head(5)

# %%
df_electricity_prices.head(5)

# %%
df_weather_to_country.head(5)

# %%
df_gas_prices.head(5)

# %%
df_historical_weather.head(5)

# %%
df_forecast_weather.head(5)

# %%
location = (pd.read_csv("/kaggle/input/fabiendaniels-mapping-locations-and-county-codes/county_lon_lats.csv")
            .drop(columns = ["Unnamed: 0"])
           )

# %%
location.head(5)

# %%
with open ('/kaggle/input/predict-energy-behavior-of-prosumers/county_id_to_name_map.json') as f:
    country_codes=json.load(f)
pd.DataFrame(country_codes,index=[0])

# %%
print("Training set :",df_training.columns)
print("Client set: ",df_client.columns)
print("Gas Prices Set :",df_gas_prices.columns)
print("Electricity Prices :",df_electricity_prices.columns)
print("Weather to Country Map :",df_weather_to_country.columns)
print("Historical Weather :",df_historical_weather.columns)
print("Forecast Weather :",df_forecast_weather.columns)

# %%
class FeatureProcessorClass():
    
    def__init__(self):
        self.weather_join=['datetime','county','data_block_id']##LatLong for county
        self.gas_join=['data_block_id']
        self.client_join=['product_type','county','data_block_id','is_business']
        self.electricity_join=['date_time','data_block_id']
        self.lat_lon_columns=['latitude','longitude']
        self.agg_stats=['mean']
